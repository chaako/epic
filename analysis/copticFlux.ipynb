# %%
from vtk import *
from math import *
import numpy as np
import matplotlib
import glob
import scipy.stats as stats
import scipy.optimize as optimize
import scipy.signal as signal
import scipy as sp
# Save as file and display instead of %pylab inline
#matplotlib.use('svg')
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.tri as tri
import matplotlib.cm as cm
import IPython.core.display as IPdisp

# %%
#folder = "/home/chaako/meshtest/fromLoki/ctzhou/v0.1"
folder = "/scratch/chaako/fromLoki/unsteadyness013"
file_names = glob.glob(folder + "/*flx*.vtk")
file_names.sort()
print len(file_names), file_names[0]
# Out:
# 2000 /scratch/chaako/fromLoki/unsteadyness013/T1e0v010P300L0e0z025x03B1e1.flx0001.vtk

# %%
vtk_readers = []
for file_name in file_names:
    reader = vtkUnstructuredGridReader()
    reader.SetFileName(file_name)
    reader.Update()
    vtk_readers.append(reader.GetOutput())
vtk_mesh = vtk_readers[0]

# %%
#for reader in vtk_readers:
#    print reader.GetNumberOfPoints()
#print vtk_readers[0]

# %%
coordinates = []
number_of_points = vtk_mesh.GetNumberOfPoints()
vtk_points = vtk_mesh.GetPoints();
for i in range(0,number_of_points):
    coordinates.append(vtk_points.GetPoint(i))
coordinates_np = np.array(coordinates)

# %%
coordinates_np_tranpose = np.transpose(coordinates_np)
x = coordinates_np_tranpose[0]
y = coordinates_np_tranpose[1]
z = coordinates_np_tranpose[2]

# %%
def getValueArrayFromVtk(vtk_reader, array_name):
    vtk_array = vtk_reader.GetPointData().GetArray(array_name)
    array = []
    for i in range(0,vtk_reader.GetNumberOfPoints()):
        array.append(vtk_array.GetValue(i))
    return array

# %%
fluxes = []
for vtk_reader in vtk_readers:
    fluxes.append(getValueArrayFromVtk(vtk_reader, "flux"))
fluxes_np = np.squeeze(np.array(fluxes))

# %%
plt.clf()
plt.plot(fluxes_np)
#plt.savefig("data.svg")
#IPdisp.SVG(filename="data.svg")
plt.savefig("data.png")
IPdisp.Image(filename="data.png")

# %%
def gaussian_smooth(data_array, sigma):
    mu = 0
    bins = np.arange(-4*sigma, 4*sigma, 1, dtype=np.float32)
    gaussian = 1/(sigma * np.sqrt(2 * np.pi))*np.exp( - (bins - mu)**2 / (2 * sigma**2) )
    return signal.convolve(data_array,gaussian,mode='same')

# %%
print fluxes_np.shape
# Out:
# (2000, 64)

# %%
fluxes_np_t = fluxes_np.transpose()
fluxes_np_smoothed_t = np.zeros(fluxes_np_t.shape, dtype=np.float32)
for j in range(0,fluxes_np_t.shape[0]):
    fluxes_np_smoothed_t[j][:] = gaussian_smooth(fluxes_np_t[j],20)
fluxes_np_smoothed = fluxes_np_smoothed_t.transpose()

# %%
plt.clf()
plt.plot(fluxes_np_smoothed)
#plt.savefig("data.svg")
#IPdisp.SVG(filename="data.svg")
plt.savefig("data.png")
IPdisp.Image(filename="data.png")

# %%
print coordinates
# Out:
# [(-0.4472712576389313, -0.18526585400104523, -0.875), (-0.7212032079696655, -0.298732191324234, -0.625), (-0.8564592003822327, -0.35475707054138184, -0.375), (-0.9166333079338074, -0.3796820044517517, -0.125), (-0.9166333079338074, -0.3796820044517517, 0.125), (-0.8564592003822327, -0.35475707054138184, 0.375), (-0.7212032079696655, -0.298732191324234, 0.625), (-0.4472712576389313, -0.18526585400104523, 0.875), (-0.18526574969291687, -0.44727128744125366, -0.875), (-0.29873204231262207, -0.7212032675743103, -0.625), (-0.3547568917274475, -0.8564592599868774, -0.375), (-0.379681795835495, -0.9166333675384521, -0.125), (-0.379681795835495, -0.9166333675384521, 0.125), (-0.3547568917274475, -0.8564592599868774, 0.375), (-0.29873204231262207, -0.7212032675743103, 0.625), (-0.18526574969291687, -0.44727128744125366, 0.875), (0.18526582419872284, -0.4472712576389313, -0.875), (0.2987321615219116, -0.7212032079696655, -0.625), (0.35475701093673706, -0.8564592003822327, -0.375), (0.37968194484710693, -0.9166333079338074, -0.125), (0.37968194484710693, -0.9166333079338074, 0.125), (0.35475701093673706, -0.8564592003822327, 0.375), (0.2987321615219116, -0.7212032079696655, 0.625), (0.18526582419872284, -0.4472712576389313, 0.875), (0.44727128744125366, -0.18526582419872284, -0.875), (0.7212032675743103, -0.2987321615219116, -0.625), (0.8564592599868774, -0.35475701093673706, -0.375), (0.9166333675384521, -0.37968194484710693, -0.125), (0.9166333675384521, -0.37968194484710693, 0.125), (0.8564592599868774, -0.35475701093673706, 0.375), (0.7212032675743103, -0.2987321615219116, 0.625), (0.44727128744125366, -0.18526582419872284, 0.875), (0.44727128744125366, 0.18526582419872284, -0.875), (0.7212032675743103, 0.2987321615219116, -0.625), (0.8564592599868774, 0.35475701093673706, -0.375), (0.9166333675384521, 0.37968194484710693, -0.125), (0.9166333675384521, 0.37968194484710693, 0.125), (0.8564592599868774, 0.35475701093673706, 0.375), (0.7212032675743103, 0.2987321615219116, 0.625), (0.44727128744125366, 0.18526582419872284, 0.875), (0.18526582419872284, 0.4472712576389313, -0.875), (0.2987321615219116, 0.7212032079696655, -0.625), (0.35475701093673706, 0.8564592003822327, -0.375), (0.37968194484710693, 0.9166333079338074, -0.125), (0.37968194484710693, 0.9166333079338074, 0.125), (0.35475701093673706, 0.8564592003822327, 0.375), (0.2987321615219116, 0.7212032079696655, 0.625), (0.18526582419872284, 0.4472712576389313, 0.875), (-0.18526574969291687, 0.44727128744125366, -0.875), (-0.29873204231262207, 0.7212032675743103, -0.625), (-0.3547568917274475, 0.8564592599868774, -0.375), (-0.379681795835495, 0.9166333675384521, -0.125), (-0.379681795835495, 0.9166333675384521, 0.125), (-0.3547568917274475, 0.8564592599868774, 0.375), (-0.29873204231262207, 0.7212032675743103, 0.625), (-0.18526574969291687, 0.44727128744125366, 0.875), (-0.4472712576389313, 0.18526585400104523, -0.875), (-0.7212032079696655, 0.298732191324234, -0.625), (-0.8564592003822327, 0.35475707054138184, -0.375), (-0.9166333079338074, 0.3796820044517517, -0.125), (-0.9166333079338074, 0.3796820044517517, 0.125), (-0.8564592003822327, 0.35475707054138184, 0.375), (-0.7212032079696655, 0.298732191324234, 0.625), (-0.4472712576389313, 0.18526585400104523, 0.875)]

# %%
plt.clf()
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(26,11), subplot_kw=dict(projection='3d'))
i=0
scts = []
for ax in axes.flat:
    if i<fluxes_np.shape[0]:
        sct = ax.scatter(x,y,z,c=fluxes[i],vmin=0,vmax=max(max(fluxes)))
        i=i+1
    else:
        sct = ax.scatter(x,y,z,vmin=0,c=fluxes[0],vmax=max(max(fluxes)))
        # Note that colorbar seems to screw up transparency/shading
        sct_ref = sct
        sct = ax.scatter(x,y,z,vmin=0,vmax=max(max(fluxes)))
    scts.append(sct)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    #ax.vew_init(0,0)
#sct_ref = scts[len(scts)-1]
fig.subplots_adjust(right=0.8)
cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
fig.colorbar(sct_ref, cax=cbar_ax)

#plt.savefig("data.svg")
#IPdisp.SVG(filename="data.svg")
plt.savefig("data.png")
IPdisp.Image(filename="data.png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-bd4c4764bbe5> in <module>()
#      20 fig.subplots_adjust(right=0.8)
#      21 cbar_ax = fig.add_axes([0.85, 0.15, 0.05, 0.7])
# ---> 22 fig.colorbar(sct_ref, cax=cbar_ax)
#      23
#      24 #plt.savefig("data.svg")
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/figure.pyc in colorbar(self, mappable, cax, ax, **kw)
#    1392                 cax, kw = cbar.make_axes(ax, **kw)
#    1393         cax.hold(True)
# -> 1394         cb = cbar.colorbar_factory(cax, mappable, **kw)
#    1395
#    1396         self.sca(ax)
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/colorbar.pyc in colorbar_factory(cax, mappable, **kwargs)
#    1171         cb = ColorbarPatch(cax, mappable, **kwargs)
#    1172     else:
# -> 1173         cb = Colorbar(cax, mappable, **kwargs)
#    1174
#    1175     mappable.callbacksSM.connect('changed', cb.on_mappable_changed)
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/colorbar.pyc in __init__(self, ax, mappable, **kw)
#     827     """
#     828     def __init__(self, ax, mappable, **kw):
# --> 829         mappable.autoscale_None() # Ensure mappable.norm.vmin, vmax
#     830                              # are set when colorbar is called,
#     831                              # even if mappable.draw has not yet
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/cm.pyc in autoscale_None(self)
#     309             raise TypeError('You must first set_array for mappable')
#     310         self.norm.autoscale_None(self._A)
# --> 311         self.changed()
#     312
#     313
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/cm.pyc in changed(self)
#     334         callbackSM listeners to the 'changed' signal
#     335         """
# --> 336         self.callbacksSM.process('changed', self)
#     337
#     338         for key in self.update_dict:
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/cbook.pyc in process(self, s, *args, **kwargs)
#     341                     del self.callbacks[s][cid]
#     342                 else:
# --> 343                     proxy(*args, **kwargs)
#     344
#     345
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/cbook.pyc in __call__(self, *args, **kwargs)
#     218             mtd = self.func
#     219         # invoke the callable and return the result
# --> 220         return mtd(*args, **kwargs)
#     221
#     222     def __eq__(self, other):
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/colorbar.pyc in on_mappable_changed(self, mappable)
#     864         self.set_cmap(mappable.get_cmap())
#     865         self.set_clim(mappable.get_clim())
# --> 866         self.update_normal(mappable)
#     867
#     868     def add_lines(self, CS, erase=True):
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/colorbar.pyc in update_normal(self, mappable)
#     895         or contour plot to which this colorbar belongs is changed.
#     896         '''
# --> 897         self.draw_all()
#     898         if isinstance(self.mappable, contour.ContourSet):
#     899             CS = self.mappable
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/colorbar.pyc in draw_all(self)
#     321         X, Y = self._mesh()
#     322         C = self._values[:, np.newaxis]
# --> 323         self._config_axes(X, Y)
#     324         if self.filled:
#     325             self._add_solids(X, Y, C)
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/colorbar.pyc in _config_axes(self, X, Y)
#     392         ax.set_ylim(*ax.dataLim.intervaly)
#     393         if self.outline is not None:
# --> 394             self.outline.remove()
#     395         self.outline = lines.Line2D(xy[:, 0], xy[:, 1], color=mpl.rcParams['axes.edgecolor'],
#     396                                     linewidth=mpl.rcParams['axes.linewidth'])
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/artist.pyc in remove(self)
#     130         # callback has one parameter, which is the child to be removed.
#     131         if self._remove_method is not None:
# --> 132             self._remove_method(self)
#     133         else:
#     134             raise NotImplementedError('cannot remove artist')
#
# /home/chaako/virtualenvs/IPython/lib/python2.7/site-packages/matplotlib-1.2.1-py2.7-linux-x86_64.egg/matplotlib/axes.pyc in <lambda>(h)
#    1469         self._set_artist_props(a)
#    1470         a.set_clip_path(self.patch)
# -> 1471         a._remove_method = lambda h: self.artists.remove(h)
#    1472         return a
#    1473
#
# ValueError: list.remove(x): x not in list

# %%
print fluxes_np.shape[1]
# Out:
# 64

# %%
print 'hello'
# Out:
# hello
